# %%
# q1
from Bio import Entrez, SeqIO 
def download_save(accession_number, output_file):
    Entrez.email = "sargun22450@iiitd.ac.in" 
    handle = Entrez.efetch(db="nucleotide", id=accession_number, rettype="fasta", retmode="text")
    sequence = handle.read()
    
    with open(output_file, "w") as f:
        f.write(sequence)

accession_number =  "NC_001144.5" 
 
output_file = "pdc.fasta"
 
download_save(accession_number, output_file)

# %%
def extract_snps(blast_file):
    with open(blast_file, 'r') as file:
        lines = file.readlines()

    snps = []

    for line in lines:
        if line.startswith("Query"):
            query_sequence = line.split()[-1]
        elif line.startswith("Sbjct"):
            subject_sequence = line.split()[-1]
            for q, s in zip(query_sequence, subject_sequence):
                if q != s:
                    position = int(line.split()[1])
                    snps.append({"position": position, "query_base": q, "subject_base": s})

    return snps

# Example usage
blast_file = "blast_results.txt"
identified_snps = extract_snps(blast_file)

# Print identified SNPs
for snp in identified_snps:
    print(f"SNP at position {snp['position']} - Query base: {snp['query_base']}, Subject base: {snp['subject_base']}")
# Out:
# SNP at position 1692 - Query base: 2, Subject base: 1
# SNP at position 1692 - Query base: 3, Subject base: 6
# SNP at position 1692 - Query base: 2, Subject base: 3
# SNP at position 1692 - Query base: 4, Subject base: 3
# SNP at position 1632 - Query base: 2, Subject base: 1
# SNP at position 1632 - Query base: 3, Subject base: 5
# SNP at position 1632 - Query base: 2, Subject base: 7
# SNP at position 1632 - Query base: 5, Subject base: 3
# SNP at position 1572 - Query base: 2, Subject base: 1
# SNP at position 1572 - Query base: 3, Subject base: 5
# SNP at position 1572 - Query base: 2, Subject base: 1
# SNP at position 1572 - Query base: 5, Subject base: 3
# SNP at position 1512 - Query base: 2, Subject base: 1
# SNP at position 1512 - Query base: 3, Subject base: 4
# SNP at position 1512 - Query base: 2, Subject base: 5
# SNP at position 1512 - Query base: 6, Subject base: 3
# SNP at position 1452 - Query base: 2, Subject base: 1
# SNP at position 1452 - Query base: 2, Subject base: 9
# SNP at position 1452 - Query base: 6, Subject base: 3
# SNP at position 1392 - Query base: 2, Subject base: 1
# SNP at position 1392 - Query base: 2, Subject base: 3
# SNP at position 1392 - Query base: 7, Subject base: 3
# SNP at position 1332 - Query base: 2, Subject base: 1
# SNP at position 1332 - Query base: 3, Subject base: 2
# SNP at position 1332 - Query base: 2, Subject base: 7
# SNP at position 1332 - Query base: 8, Subject base: 3
# SNP at position 1272 - Query base: 2, Subject base: 1
# SNP at position 1272 - Query base: 3, Subject base: 2
# SNP at position 1272 - Query base: 2, Subject base: 1
# SNP at position 1272 - Query base: 8, Subject base: 3
# SNP at position 1212 - Query base: 2, Subject base: 1
# SNP at position 1212 - Query base: 3, Subject base: 1
# SNP at position 1212 - Query base: 2, Subject base: 5
# SNP at position 1212 - Query base: 9, Subject base: 3
# SNP at position 1152 - Query base: 2, Subject base: 1
# SNP at position 1152 - Query base: 3, Subject base: 0
# SNP at position 1152 - Query base: 2, Subject base: 9
# SNP at position 1152 - Query base: 9, Subject base: 3
# SNP at position 1092 - Query base: 2, Subject base: 1
# SNP at position 1092 - Query base: 3, Subject base: 0
# SNP at position 1092 - Query base: 0, Subject base: 3
# SNP at position 1032 - Query base: 2, Subject base: 9
# SNP at position 1032 - Query base: 3, Subject base: 7
# SNP at position 972 - Query base: 2, Subject base: 9
# SNP at position 972 - Query base: 3, Subject base: 1
# SNP at position 912 - Query base: 2, Subject base: 8
# SNP at position 912 - Query base: 3, Subject base: 5
# SNP at position 852 - Query base: 2, Subject base: 7
# SNP at position 852 - Query base: 3, Subject base: 9
# SNP at position 792 - Query base: 2, Subject base: 7
# SNP at position 732 - Query base: 2, Subject base: 6
# SNP at position 732 - Query base: 3, Subject base: 7
# SNP at position 672 - Query base: 2, Subject base: 6
# SNP at position 672 - Query base: 3, Subject base: 1
# SNP at position 612 - Query base: 2, Subject base: 5
# SNP at position 612 - Query base: 3, Subject base: 5
# SNP at position 552 - Query base: 2, Subject base: 4
# SNP at position 552 - Query base: 3, Subject base: 9
# SNP at position 492 - Query base: 2, Subject base: 4
# SNP at position 432 - Query base: 2, Subject base: 3
# SNP at position 432 - Query base: 3, Subject base: 7
# SNP at position 372 - Query base: 2, Subject base: 3
# SNP at position 372 - Query base: 3, Subject base: 1
# SNP at position 312 - Query base: 3, Subject base: 5
# SNP at position 252 - Query base: 2, Subject base: 1
# SNP at position 252 - Query base: 3, Subject base: 9
# SNP at position 192 - Query base: 2, Subject base: 1
# SNP at position 132 - Query base: 2, Subject base: 7
# SNP at position 72 - Query base: 2, Subject base: 1
# SNP at position 12 - Query base: 2, Subject base: 1
# SNP at position 1 - Query base: 4, Subject base: 6
# SNP at position 1 - Query base: 1, Subject base: 0
# SNP at position 61 - Query base: 4, Subject base: 1
# SNP at position 61 - Query base: 0, Subject base: 9
# SNP at position 120 - Query base: 4, Subject base: 1
# SNP at position 120 - Query base: 1, Subject base: 7
# SNP at position 120 - Query base: 0, Subject base: 9
# SNP at position 180 - Query base: 4, Subject base: 2
# SNP at position 180 - Query base: 1, Subject base: 3
# SNP at position 180 - Query base: 0, Subject base: 9
# SNP at position 240 - Query base: 4, Subject base: 2
# SNP at position 240 - Query base: 1, Subject base: 9
# SNP at position 240 - Query base: 1, Subject base: 9
# SNP at position 300 - Query base: 4, Subject base: 3
# SNP at position 300 - Query base: 1, Subject base: 5
# SNP at position 300 - Query base: 1, Subject base: 9
# SNP at position 360 - Query base: 1, Subject base: 9
# SNP at position 420 - Query base: 1, Subject base: 7
# SNP at position 420 - Query base: 1, Subject base: 9
# SNP at position 480 - Query base: 4, Subject base: 5
# SNP at position 480 - Query base: 1, Subject base: 3
# SNP at position 480 - Query base: 1, Subject base: 9
# SNP at position 540 - Query base: 4, Subject base: 5
# SNP at position 540 - Query base: 1, Subject base: 9
# SNP at position 540 - Query base: 1, Subject base: 9
# SNP at position 600 - Query base: 4, Subject base: 6
# SNP at position 600 - Query base: 1, Subject base: 5
# SNP at position 600 - Query base: 1, Subject base: 8
# SNP at position 659 - Query base: 4, Subject base: 7
# SNP at position 659 - Query base: 1, Subject base: 8
# SNP at position 719 - Query base: 4, Subject base: 7
# SNP at position 719 - Query base: 1, Subject base: 7
# SNP at position 719 - Query base: 1, Subject base: 8
# SNP at position 779 - Query base: 4, Subject base: 8
# SNP at position 779 - Query base: 1, Subject base: 3
# SNP at position 779 - Query base: 1, Subject base: 8
# SNP at position 839 - Query base: 4, Subject base: 8
# SNP at position 839 - Query base: 1, Subject base: 9
# SNP at position 839 - Query base: 1, Subject base: 8
# SNP at position 899 - Query base: 4, Subject base: 9
# SNP at position 899 - Query base: 1, Subject base: 5
# SNP at position 899 - Query base: 1, Subject base: 8
# SNP at position 959 - Query base: 4, Subject base: 1
# SNP at position 959 - Query base: 1, Subject base: 0
# SNP at position 959 - Query base: 7, Subject base: 8
# SNP at position 1019 - Query base: 4, Subject base: 1
# SNP at position 1019 - Query base: 1, Subject base: 0
# SNP at position 1019 - Query base: 1, Subject base: 7
# SNP at position 1019 - Query base: 7, Subject base: 5
# SNP at position 1076 - Query base: 4, Subject base: 1
# SNP at position 1076 - Query base: 1, Subject base: 3
# SNP at position 1076 - Query base: 8, Subject base: 5
# SNP at position 1136 - Query base: 4, Subject base: 1
# SNP at position 1136 - Query base: 1, Subject base: 9
# SNP at position 1136 - Query base: 9, Subject base: 5
# SNP at position 1196 - Query base: 4, Subject base: 1
# SNP at position 1196 - Query base: 1, Subject base: 2
# SNP at position 1196 - Query base: 1, Subject base: 5
# SNP at position 1196 - Query base: 9, Subject base: 3
# SNP at position 1254 - Query base: 4, Subject base: 1
# SNP at position 1254 - Query base: 1, Subject base: 3
# SNP at position 1254 - Query base: 2, Subject base: 1
# SNP at position 1254 - Query base: 0, Subject base: 2
# SNP at position 1313 - Query base: 4, Subject base: 1
# SNP at position 1313 - Query base: 1, Subject base: 3
# SNP at position 1313 - Query base: 2, Subject base: 7
# SNP at position 1313 - Query base: 0, Subject base: 2
# SNP at position 1373 - Query base: 4, Subject base: 1
# SNP at position 1373 - Query base: 1, Subject base: 4
# SNP at position 1373 - Query base: 2, Subject base: 3
# SNP at position 1373 - Query base: 1, Subject base: 2
# SNP at position 1433 - Query base: 4, Subject base: 1
# SNP at position 1433 - Query base: 1, Subject base: 4
# SNP at position 1433 - Query base: 2, Subject base: 9
# SNP at position 1493 - Query base: 4, Subject base: 1
# SNP at position 1493 - Query base: 1, Subject base: 5
# SNP at position 1493 - Query base: 2, Subject base: 5
# SNP at position 1553 - Query base: 4, Subject base: 1
# SNP at position 1553 - Query base: 1, Subject base: 6
# SNP at position 1553 - Query base: 2, Subject base: 1
# SNP at position 1553 - Query base: 3, Subject base: 1
# SNP at position 1612 - Query base: 4, Subject base: 1
# SNP at position 1612 - Query base: 1, Subject base: 6
# SNP at position 1612 - Query base: 2, Subject base: 7
# SNP at position 1612 - Query base: 3, Subject base: 1
# SNP at position 1672 - Query base: 4, Subject base: 1
# SNP at position 1672 - Query base: 1, Subject base: 6
# SNP at position 1672 - Query base: 2, Subject base: 9
# SNP at position 1672 - Query base: 4, Subject base: 2
